# %% [markdown]
# <a href="https://colab.research.google.com/github/furingleb/-/blob/main/Copy_of_visual_chatgpt_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/K-tang-mkv/visual-chatgpt-googlecolab
# Out:
# Cloning into 'visual-chatgpt-googlecolab'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 139 (delta 63), reused 51 (delta 51), pack-reused 64
# Receiving objects: 100% (139/139), 6.23 MiB | 14.86 MiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %%
# !nvidia-smi
# Out:
# Sun Aug 20 08:54:26 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %cd visual-chatgpt-googlecolab
# Out:
# /content/visual-chatgpt-googlecolab

# %% [markdown]
# ## Create a conda virtual environment with python=3.8

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
#
# conda install --channel defaults conda python=3.8 --yes
# conda update --channel defaults --all --yes
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libffi-3.3                 |       he6710b0_2          54 KB
#     ruamel.yaml-0.16.12        |   py38h7b6447c_1         167 KB
#     pluggy-1.0.0               |   py38h06a4308_1          28 KB
#     pysocks-1.7.1              |   py38h06a4308_0          31 KB
#     pip-23.0.1                 |   py38h06a4308_0         2.5 MB
#     ncurses-6.3                |       h7f8727e_2         1.0 MB
#     python-3.8.13              |       h12debd9_0        22.7 MB
#     cryptography-39.0.1        |   py38h9ce1e76_0         1.5 MB
#     sqlite-3.38.5              |       hc218d9a_0         1.5 MB
#     conda-package-streaming-0.7.0|   py38h06a4308_0          25 KB
#     setuptools-65.6.3          |   py38h06a4308_0         1.4 MB
#     openssl-1.1.1t             |       h7f8727e_0         3.8 MB
#     pycosat-0.6.3              |   py38h7b6447c_1         107 KB
#     ld_impl_linux-64-2.38      |       h1181459_1         732 KB
#     toolz-0.12.0               |   py38h06a4308_0          99 KB
#     tqdm-4.64.1                |   py38h06a4308_0         122 KB
#     zlib-1.2.12                |       h7f8727e_2         130 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     brotlipy-0.7.0             |py38h27cfd23_1003         349 KB
#     pyopenssl-23.0.0           |   py38h06a4308_0          89 KB
#     zstandard-0.15.2           |   py38h27cfd23_0         599 KB
#     wheel-0.38.4               |   py38h06a4308_0          58 KB
#     conda-package-handling-2.0.2|   py38h06a4308_0         268 KB
#     readline-8.1.2             |       h7f8727e_1         423 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     ca-certificates-2023.01.10 |       h06a4308_0         127 KB
#     pycparser-2.21             |     pyhd3eb1b0_0          94 KB
#     conda-23.1.0               |   py38h06a4308_0         958 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     certifi-2022.12.7          |   py38h06a4308_0         152 KB
#     tk-8.6.12                  |       h1ccaba5_0         3.3 MB
#     idna-3.4                   |   py38h06a4308_0         109 KB
#     cffi-1.15.0                |   py38hd667e15_1         226 KB
#     urllib3-1.26.14            |   py38h06a4308_0         178 KB
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          33 KB
#     requests-2.28.1            |   py38h06a4308_0          92 KB
#     xz-5.2.5                   |       h7f8727e_1         389 KB
#     ruamel.yaml.clib-0.2.6     |   py38h7f8727e_0         146 KB
#     ------------------------------------------------------------
#                                            Total:        55.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:           0.1-main
#     brotlipy:                0.7.0-py38h27cfd23_1003
#     charset-normalizer:      2.0.4-pyhd3eb1b0_0
#     conda-package-handling:  2.0.2-py38h06a4308_0
#     conda-package-streaming: 0.7.0-py38h06a4308_0
#     ld_impl_linux-64:        2.38-h1181459_1
#     pluggy:                  1.0.0-py38h06a4308_1
#     ruamel.yaml:             0.16.12-py38h7b6447c_1
#     ruamel.yaml.clib:        0.2.6-py38h7f8727e_0
#     toolz:                   0.12.0-py38h06a4308_0
#     tqdm:                    4.64.1-py38h06a4308_0
#     zstandard:               0.15.2-py38h27cfd23_0
#
# The following packages will be UPDATED:
#
#     ca-certificates:         2018.03.07-0            --> 2023.01.10-h06a4308_0
#     certifi:                 2018.4.16-py36_0        --> 2022.12.7-py38h06a4308_0
#     cffi:                    1.11.5-py36h9745a5d_0   --> 1.15.0-py38hd667e15_1
#     conda:                   4.5.4-py36_0            --> 23.1.0-py38h06a4308_0
#     cryptography:            2.2.2-py36h14c3975_0    --> 39.0.1-py38h9ce1e76_0
#     idna:                    2.6-py36h82fb2a8_1      --> 3.4-py38h06a4308_0
#     libffi:                  3.2.1-hd88cf55_4        --> 3.3-he6710b0_2
#     libgcc-ng:               7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     libstdcxx-ng:            7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     ncurses:                 6.1-hf484d3e_0          --> 6.3-h7f8727e_2
#     openssl:                 1.0.2o-h20670df_0       --> 1.1.1t-h7f8727e_0
#     pip:                     10.0.1-py36_0           --> 23.0.1-py38h06a4308_0
#     pycosat:                 0.6.3-py36h0a5515d_0    --> 0.6.3-py38h7b6447c_1
#     pycparser:               2.18-py36hf9f622e_1     --> 2.21-pyhd3eb1b0_0
#     pyopenssl:               18.0.0-py36_0           --> 23.0.0-py38h06a4308_0
#     pysocks:                 1.6.8-py36_0            --> 1.7.1-py38h06a4308_0
#     python:                  3.6.5-hc3d631a_2        --> 3.8.13-h12debd9_0
#     readline:                7.0-ha6073c6_4          --> 8.1.2-h7f8727e_1
#     requests:                2.18.4-py36he2e5f8d_1   --> 2.28.1-py38h06a4308_0
#     setuptools:              39.2.0-py36_0           --> 65.6.3-py38h06a4308_0
#     sqlite:                  3.23.1-he433501_0       --> 3.38.5-hc218d9a_0
#     tk:                      8.6.7-hc745277_3        --> 8.6.12-h1ccaba5_0
#     urllib3:                 1.22-py36hbe7ace6_0     --> 1.26.14-py38h06a4308_0
#     wheel:                   0.31.1-py36_0           --> 0.38.4-py38h06a4308_0
#     xz:                      5.2.4-h14c3975_4        --> 5.2.5-h7f8727e_1
#     zlib:                    1.2.11-ha838bed_2       --> 1.2.12-h7f8727e_2
#
#
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     cffi-1.15.1                |   py38h5eee18b_3         241 KB
#     libffi-3.4.2               |       h6a678d5_6         136 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     ncurses-6.4                |       h6a678d5_0         914 KB
#     pycosat-0.6.4              |   py38h5eee18b_0          84 KB
#     python-3.8.16              |       h7a1cb2a_3        23.7 MB
#     readline-8.2               |       h5eee18b_0         357 KB
#     ruamel.yaml-0.17.21        |   py38h5eee18b_0         178 KB
#     ruamel.yaml.clib-0.2.6     |   py38h5eee18b_1         143 KB
#     sqlite-3.40.1              |       h5082296_0         1.2 MB
#     xz-5.2.10                  |       h5eee18b_1         429 KB
#     zlib-1.2.13                |       h5eee18b_0         103 KB
#     zstandard-0.19.0           |   py38h5eee18b_0         474 KB
#     ------------------------------------------------------------
#                                            Total:        38.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#
# The following packages will be UPDATED:
#
#   cffi                                1.15.0-py38hd667e15_1 --> 1.15.1-py38h5eee18b_3
#   libffi                                     3.3-he6710b0_2 --> 3.4.2-h6a678d5_6
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   libstdcxx-ng                             9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   ncurses                                    6.3-h7f8727e_2 --> 6.4-h6a678d5_0
#   pycosat                              0.6.3-py38h7b6447c_1 --> 0.6.4-py38h5eee18b_0
#   python                                  3.8.13-h12debd9_0 --> 3.8.16-h7a1cb2a_3
#   readline                                 8.1.2-h7f8727e_1 --> 8.2-h5eee18b_0
#   ruamel.yaml                        0.16.12-py38h7b6447c_1 --> 0.17.21-py38h5eee18b_0
#   ruamel.yaml.clib                     0.2.6-py38h7f8727e_0 --> 0.2.6-py38h5eee18b_1
#   sqlite                                  3.38.5-hc218d9a_0 --> 3.40.1-h5082296_0
#   xz                                       5.2.5-h7f8727e_1 --> 5.2.10-h5eee18b_1
#   zlib                                    1.2.12-h7f8727e_2 --> 1.2.13-h5eee18b_0
#   zstandard                           0.15.2-py38h27cfd23_0 --> 0.19.0-py38h5eee18b_0
#
#
#
# Downloading and Extracting Packages
# zlib-1.2.13          | 103 KB    |            |   0%
# sqlite-3.40.1        | 1.2 MB    |            |   0%
#
# readline-8.2         | 357 KB    |            |   0%
#
#
# libgomp-11.2.0       | 474 KB    |            |   0%
#
#
#
# cffi-1.15.1          | 241 KB    |            |   0%
#
#
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    |            |   0%
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    |            |   0%
#
#
#
#
#
#
# ruamel.yaml-0.17.21  | 178 KB    |            |   0%
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    |            |   0%
#
#
#
#
#
#
#
#
# ruamel.yaml.clib-0.2 | 143 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# libffi-3.4.2         | 136 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# python-3.8.16        | 23.7 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.19.0     | 474 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.4        | 84 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.2.10            | 429 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     |            |   0%
# zlib-1.2.13          | 103 KB    | ######1    |  62%
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    |            |   0%
#
#
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | 9          |  10%
#
#
#
#
#
#
# ruamel.yaml-0.17.21  | 178 KB    | 8          |   9%
#
#
#
#
#
#
#
#
# ruamel.yaml.clib-0.2 | 143 KB    | #1         |  11%
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | 1          |   2%
#
#
#
#
#
#
#
#
#
# libffi-3.4.2         | 136 KB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
# python-3.8.16        | 23.7 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.19.0     | 474 KB    | 3          |   3%
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.4        | 84 KB     | #9         |  19%
#
#
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | ####1      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.2.10            | 429 KB    | 3          |   4%
#
#
#
#
#
#
#
#
#
#
# python-3.8.16        | 23.7 MB   | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | #######6   |  77%
#
# readline-8.2         | 357 KB    | ########## | 100%
#
# readline-8.2         | 357 KB    | ########## | 100%
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | ######     |  60%
#
#
# libgomp-11.2.0       | 474 KB    | ########## | 100%
#
#
# libgomp-11.2.0       | 474 KB    | ########## | 100%
#
#
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 103 KB    | ########## | 100%
#
#
#
# cffi-1.15.1          | 241 KB    | ########## | 100%
#
#
#
# cffi-1.15.1          | 241 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# python-3.8.16        | 23.7 MB   | ##8        |  28%
# sqlite-3.40.1        | 1.2 MB    | ########## | 100%
# sqlite-3.40.1        | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
# ruamel.yaml-0.17.21  | 178 KB    | ########## | 100%
#
#
#
#
#
#
# ruamel.yaml-0.17.21  | 178 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# ruamel.yaml.clib-0.2 | 143 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# ruamel.yaml.clib-0.2 | 143 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# python-3.8.16        | 23.7 MB   | ####2      |  42%
#
#
#
#
#
#
#
#
#
#
# python-3.8.16        | 23.7 MB   | #####8     |  58%
#
#
#
#
#
#
#
#
#
# libffi-3.4.2         | 136 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libffi-3.4.2         | 136 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.4        | 84 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.4        | 84 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# python-3.8.16        | 23.7 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.19.0     | 474 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.19.0     | 474 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# python-3.8.16        | 23.7 MB   | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.2.10            | 429 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.2.10            | 429 KB    | ########## | 100%
#
#
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########## | 100%
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | ########## | 100%
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# python-3.8.16        | 23.7 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# --2023-03-13 09:03:16--  https://repo.continuum.io/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh [following]
# --2023-03-13 09:03:16--  https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
#      0K .......... .......... .......... .......... ..........  0% 25.3M 2s
#     50K .......... .......... .......... .......... ..........  0% 33.1M 2s
#    100K .......... .......... .......... .......... ..........  0% 56.5M 2s
#    150K .......... .......... .......... .......... ..........  0% 54.0M 1s
#    200K .......... .......... .......... .......... ..........  0% 59.6M 1s
#    250K .......... .......... .......... .......... ..........  0% 64.0M 1s
#    300K .......... .......... .......... .......... ..........  0% 61.7M 1s
#    350K .......... .......... .......... .......... ..........  0% 49.0M 1s
#    400K .......... .......... .......... .......... ..........  0% 61.5M 1s
#    450K .......... .......... .......... .......... ..........  0% 58.2M 1s
#    500K .......... .......... .......... .......... ..........  0% 58.3M 1s
#    550K .......... .......... .......... .......... ..........  1% 52.8M 1s
#    600K .......... .......... .......... .......... ..........  1% 62.5M 1s
#    650K .......... .......... .......... .......... ..........  1% 62.6M 1s
#    700K .......... .......... .......... .......... ..........  1% 60.4M 1s
#    750K .......... .......... .......... .......... ..........  1% 54.7M 1s
#    800K .......... .......... .......... .......... ..........  1% 45.7M 1s
#    850K .......... .......... .......... .......... ..........  1% 59.7M 1s
#    900K .......... .......... .......... .......... ..........  1% 57.4M 1s
#    950K .......... .......... .......... .......... ..........  1% 40.3M 1s
# certifi-2022.12.7    |  152 KB | ########## | 100%
# tk-8.6.12            |  3.3 MB | ########## | 100%
# idna-3.4             |  109 KB | ########## | 100%
# cffi-1.15.0          |  226 KB | ########## | 100%
# urllib3-1.26.14      |  178 KB | ########## | 100%
# charset-normalizer-2 |   33 KB | ########## | 100%
# requests-2.28.1      |   92 KB | ########## | 100%
# xz-5.2.5             |  389 KB | ########## | 100%
# ruamel.yaml.clib-0.2 |  146 KB | ########## | 100%
#
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::chardet==3.0.4=py36h0f667ec_1
#   - defaults/linux-64::ruamel_yaml==0.15.37=py36h14c3975_2
#   - defaults/linux-64::yaml==0.1.7=had09818_2
#   - defaults/linux-64::asn1crypto==0.24.0=py36_0
#   - defaults/linux-64::six==1.11.0=py36h372c433_1

# %%
import sys
sys.path.append("/usr/local/lib/python3.8/site-packages")

# %% [markdown]
# ## Use python3.8 to install all the packages we need

# %%
# !python3.8 -m pip install -r requirement.txt

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ---------------
# absl-py                   1.4.0
# accelerate                0.17.0
# addict                    2.4.0
# aiofiles                  23.1.0
# aiohttp                   3.8.4
# aiosignal                 1.3.1
# albumentations            1.3.0
# altair                    4.2.2
# antlr4-python3-runtime    4.8
# anyio                     3.6.2
# async-timeout             4.0.2
# attrs                     22.2.0
# backports.zoneinfo        0.2.1
# basicsr                   1.4.2
# blinker                   1.5
# braceexpand               0.1.7
# brotlipy                  0.7.0
# cachetools                5.3.0
# certifi                   2022.12.7
# cffi                      1.15.1
# charset-normalizer        2.0.4
# click                     8.1.3
# coloredlogs               15.0.1
# conda                     23.1.0
# conda-package-handling    2.0.2
# conda_package_streaming   0.7.0
# contourpy                 1.0.7
# cryptography              39.0.1
# cycler                    0.11.0
# dataclasses-json          0.5.7
# decorator                 5.1.1
# diffusers                 0.14.0
# einops                    0.3.0
# entrypoints               0.4
# fastapi                   0.94.0
# ffmpy                     0.3.0
# filelock                  3.9.0
# flatbuffers               23.3.3
# fonttools                 4.39.0
# frozenlist                1.3.3
# fsspec                    2023.3.0
# ftfy                      6.1.1
# future                    0.18.3
# gitdb                     4.0.10
# GitPython                 3.1.31
# google-auth               2.16.2
# google-auth-oauthlib      0.4.6
# gradio                    3.20.1
# greenlet                  2.0.2
# grpcio                    1.51.3
# h11                       0.14.0
# httpcore                  0.16.3
# httpx                     0.23.3
# huggingface-hub           0.13.1
# humanfriendly             10.0
# idna                      3.4
# imageio                   2.9.0
# imageio-ffmpeg            0.4.2
# importlib-metadata        6.0.0
# importlib-resources       5.12.0
# invisible-watermark       0.1.5
# Jinja2                    3.1.2
# joblib                    1.2.0
# jsonschema                4.17.3
# kiwisolver                1.4.4
# kornia                    0.6.0
# langchain                 0.0.101
# lazy_loader               0.1
# linkify-it-py             2.0.0
# lmdb                      1.4.0
# Markdown                  3.4.1
# markdown-it-py            2.2.0
# MarkupSafe                2.1.2
# marshmallow               3.19.0
# marshmallow-enum          1.5.1
# matplotlib                3.7.1
# mdit-py-plugins           0.3.3
# mdurl                     0.1.2
# mpmath                    1.3.0
# multidict                 6.0.4
# mypy-extensions           1.0.0
# networkx                  3.0
# numpy                     1.23.1
# oauthlib                  3.2.2
# omegaconf                 2.1.1
# onnx                      1.13.1
# onnxruntime               1.14.1
# open-clip-torch           2.0.2
# openai                    0.27.2
# opencv-python             4.5.1.48
# opencv-python-headless    4.7.0.72
# orjson                    3.8.7
# packaging                 23.0
# pandas                    1.5.3
# Pillow                    9.4.0
# pip                       23.0.1
# pkgutil_resolve_name      1.3.10
# pluggy                    1.0.0
# prettytable               3.6.0
# protobuf                  3.20.3
# psutil                    5.9.4
# pyarrow                   11.0.0
# pyasn1                    0.4.8
# pyasn1-modules            0.2.8
# pycosat                   0.6.4
# pycparser                 2.21
# pycryptodome              3.17
# pydantic                  1.10.6
# pydeck                    0.8.0
# pyDeprecate               0.3.1
# pydub                     0.25.1
# Pygments                  2.14.0
# Pympler                   1.0.1
# pyOpenSSL                 23.0.0
# pyparsing                 3.0.9
# pyrsistent                0.19.3
# PySocks                   1.7.1
# python-dateutil           2.8.2
# python-multipart          0.0.6
# pytorch-lightning         1.5.0
# pytz                      2022.7.1
# pytz-deprecation-shim     0.1.0.post0
# PyWavelets                1.4.1
# PyYAML                    6.0
# qudida                    0.0.4
# regex                     2022.10.31
# requests                  2.28.1
# requests-oauthlib         1.3.1
# rfc3986                   1.5.0
# rich                      13.3.2
# rsa                       4.9
# ruamel.yaml               0.17.21
# ruamel.yaml.clib          0.2.6
# safetensors               0.2.7
# scikit-image              0.20.0
# scikit-learn              1.2.2
# scipy                     1.9.1
# semver                    2.13.0
# setuptools                65.6.3
# six                       1.16.0
# smmap                     5.0.0
# sniffio                   1.3.0
# SQLAlchemy                1.4.46
# starlette                 0.26.0.post1
# streamlit                 1.12.1
# streamlit-drawable-canvas 0.8.0
# sympy                     1.11.1
# tb-nightly                2.13.0a20230312
# tenacity                  8.2.2
# tensorboard               2.12.0
# tensorboard-data-server   0.7.0
# tensorboard-plugin-wit    1.8.1
# test-tube                 0.7.5
# threadpoolctl             3.1.0
# tifffile                  2023.2.28
# timm                      0.6.12
# tokenizers                0.13.2
# toml                      0.10.2
# toolz                     0.12.0
# torch                     1.12.1
# torchmetrics              0.6.0
# torchvision               0.13.1
# tornado                   6.2
# tqdm                      4.64.1
# transformers              4.26.1
# typing_extensions         4.5.0
# typing-inspect            0.8.0
# tzdata                    2022.7
# tzlocal                   4.2
# uc-micro-py               1.0.1
# urllib3                   1.26.14
# uvicorn                   0.21.0
# validators                0.20.0
# watchdog                  2.3.1
# wcwidth                   0.2.6
# webdataset                0.2.5
# websockets                10.4
# Werkzeug                  2.2.3
# wheel                     0.38.4
# yapf                      0.32.0
# yarl                      1.8.2
# zipp                      3.15.0
# zstandard                 0.19.0

# %%
# !nvidia-smi
# Out:
# Mon Mar 13 09:20:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    24W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Clone controlnet repo, and I don't download any controlnet models here

# %%
# !bash download.sh
# Out:
# Cloning into 'ControlNet'...
# remote: Enumerating objects: 1264, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 1264 (delta 6), reused 6 (delta 1), pack-reused 1252
# Receiving objects: 100% (1264/1264), 122.36 MiB | 34.90 MiB/s, done.
# Resolving deltas: 100% (547/547), done.

# %%
# %env OPENAI_API_KEY=key

# %%
# !mkdir ./image

# %%
# !python visual_chatgpt.py
# Out:
# Initializing VisualChatGPT
# Initializing ImageCaptioning to cuda:0
# Downloading (…)rocessor_config.json: 100% 287/287 [00:00<00:00, 34.0kB/s]
# Downloading (…)okenizer_config.json: 100% 438/438 [00:00<00:00, 57.5kB/s]
# Downloading (…)solve/main/vocab.txt: 100% 232k/232k [00:00<00:00, 28.5MB/s]
# Downloading (…)cial_tokens_map.json: 100% 125/125 [00:00<00:00, 49.0kB/s]
# Downloading (…)lve/main/config.json: 100% 4.56k/4.56k [00:00<00:00, 657kB/s]
# Downloading pytorch_model.bin: 100% 990M/990M [00:05<00:00, 171MB/s]
# Initializing T2I to cuda:0
# Downloading (…)ain/model_index.json: 100% 543/543 [00:00<00:00, 72.4kB/s]
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading (…)rocessor_config.json:   0% 0.00/342 [00:00<?, ?B/s]
#
# Downloading (…)rocessor_config.json: 100% 342/342 [00:00<00:00, 8.00kB/s]
# Downloading (…)_checker/config.json: 100% 4.72k/4.72k [00:00<00:00, 204kB/s]
#
# Downloading model.safetensors:   0% 0.00/1.22G [00:00<?, ?B/s]
#
# Downloading (…)cheduler_config.json: 100% 308/308 [00:00<00:00, 22.0kB/s]
#
#
# Downloading (…)_encoder/config.json:   0% 0.00/617 [00:00<?, ?B/s]
#
#
# Downloading (…)cial_tokens_map.json:   0% 0.00/472 [00:00<?, ?B/s]
#
#
#
# Downloading (…)_encoder/config.json: 100% 617/617 [00:00<00:00, 18.9kB/s]
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 10.6kB/s]
#
#
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 7.51MB/s]
#
# Downloading model.safetensors:   1% 10.5M/1.22G [00:00<00:24, 48.4MB/s]
#
#
#
# Downloading model.safetensors:   2% 10.5M/492M [00:00<00:08, 57.6MB/s]
#
# Downloading (…)okenizer_config.json: 100% 806/806 [00:00<00:00, 119kB/s]
#
#
# Downloading (…)819/unet/config.json: 100% 743/743 [00:00<00:00, 40.3kB/s]
#
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
# Downloading (…)d819/vae/config.json: 100% 547/547 [00:00<00:00, 177kB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 18.6MB/s]
#
#
#
#
# Downloading model.safetensors:   4% 21.0M/492M [00:00<00:07, 63.6MB/s]
#
# Downloading (…)ch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 10.5M/3.44G [00:00<00:40, 84.1MB/s]
#
#
#
# Downloading model.safetensors:   6% 31.5M/492M [00:00<00:06, 74.7MB/s]
# Downloading model.safetensors:   3% 31.5M/1.22G [00:00<00:17, 66.1MB/s]
#
# Downloading (…)ch_model.safetensors:   6% 21.0M/335M [00:00<00:03, 83.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 21.0M/3.44G [00:00<00:47, 72.0MB/s]
# Downloading model.safetensors:   3% 41.9M/1.22G [00:00<00:17, 65.3MB/s]
#
#
#
# Downloading model.safetensors:   9% 41.9M/492M [00:00<00:06, 67.2MB/s]
#
#
#
# Downloading model.safetensors:  11% 52.4M/492M [00:01<00:20, 21.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 31.5M/3.44G [00:01<03:12, 17.7MB/s]
# Downloading model.safetensors:   4% 52.4M/1.22G [00:01<00:56, 20.7MB/s]
#
# Downloading (…)ch_model.safetensors:   9% 31.5M/335M [00:01<00:15, 19.0MB/s]
#
#
#
# Downloading model.safetensors:  13% 62.9M/492M [00:01<00:14, 29.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 41.9M/3.44G [00:01<02:11, 25.8MB/s]
#
# Downloading (…)ch_model.safetensors:  13% 41.9M/335M [00:01<00:11, 25.3MB/s]
# Downloading model.safetensors:   5% 62.9M/1.22G [00:01<00:43, 26.2MB/s]
#
#
#
# Downloading model.safetensors:  15% 73.4M/492M [00:02<00:24, 17.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 52.4M/3.44G [00:02<03:32, 15.9MB/s]
# Downloading model.safetensors:   6% 73.4M/1.22G [00:03<01:06, 17.2MB/s]
#
# Downloading (…)ch_model.safetensors:  16% 52.4M/335M [00:02<00:17, 16.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 62.9M/3.44G [00:02<02:32, 22.1MB/s]
#
#
#
# Downloading model.safetensors:  17% 83.9M/492M [00:03<00:18, 22.5MB/s]
#
# Downloading (…)ch_model.safetensors:  19% 62.9M/335M [00:02<00:12, 22.5MB/s]
# Downloading model.safetensors:   7% 83.9M/1.22G [00:03<00:52, 21.7MB/s]
#
#
#
# Downloading model.safetensors:  19% 94.4M/492M [00:03<00:13, 28.5MB/s]
#
# Downloading (…)ch_model.safetensors:  22% 73.4M/335M [00:02<00:09, 28.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 73.4M/3.44G [00:03<02:27, 22.9MB/s]
#
#
#
# Downloading model.safetensors:  21% 105M/492M [00:04<00:21, 18.4MB/s]
# Downloading model.safetensors:   8% 94.4M/1.22G [00:04<01:13, 15.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 83.9M/3.44G [00:04<03:07, 17.9MB/s]
#
#
#
# Downloading model.safetensors:  23% 115M/492M [00:04<00:15, 24.5MB/s]
#
# Downloading (…)ch_model.safetensors:  25% 83.9M/335M [00:04<00:14, 17.3MB/s]
# Downloading model.safetensors:   9% 105M/1.22G [00:04<00:56, 19.8MB/s]
#
# Downloading (…)ch_model.safetensors:  28% 94.4M/335M [00:04<00:10, 22.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 94.4M/3.44G [00:04<02:25, 23.0MB/s]
#
#
#
# Downloading model.safetensors:  26% 126M/492M [00:04<00:11, 30.6MB/s]
#
#
#
# Downloading model.safetensors:  28% 136M/492M [00:04<00:09, 38.6MB/s]
# Downloading model.safetensors:   9% 115M/1.22G [00:04<00:43, 25.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 105M/3.44G [00:04<01:59, 27.8MB/s]
#
# Downloading (…)ch_model.safetensors:  34% 115M/335M [00:04<00:06, 35.1MB/s]
#
#
#
# Downloading model.safetensors:  30% 147M/492M [00:04<00:07, 45.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 115M/3.44G [00:04<01:35, 34.8MB/s]
#
# Downloading (…)ch_model.safetensors:  38% 126M/335M [00:04<00:05, 40.9MB/s]
#
#
#
# Downloading model.safetensors:  32% 157M/492M [00:04<00:06, 51.9MB/s]
# Downloading model.safetensors:  11% 136M/1.22G [00:04<00:28, 37.5MB/s]
#
# Downloading (…)ch_model.safetensors:  41% 136M/335M [00:04<00:04, 48.2MB/s]
#
#
#
# Downloading model.safetensors:  34% 168M/492M [00:05<00:05, 58.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 136M/3.44G [00:04<01:06, 49.8MB/s]
# Downloading model.safetensors:  12% 147M/1.22G [00:05<00:25, 41.7MB/s]
#
# Downloading (…)ch_model.safetensors:  44% 147M/335M [00:04<00:03, 56.1MB/s]
#
#
#
# Downloading model.safetensors:  36% 178M/492M [00:05<00:04, 67.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 147M/3.44G [00:04<00:58, 56.4MB/s]
#
#
#
# Downloading model.safetensors:  38% 189M/492M [00:06<00:12, 24.4MB/s]
# Downloading model.safetensors:  13% 157M/1.22G [00:06<00:49, 21.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 157M/3.44G [00:05<02:09, 25.4MB/s]
#
# Downloading (…)ch_model.safetensors:  47% 157M/335M [00:05<00:07, 23.3MB/s]
#
#
#
# Downloading model.safetensors:  43% 210M/492M [00:06<00:07, 40.0MB/s]
#
# Downloading (…)ch_model.safetensors:  50% 168M/335M [00:05<00:05, 29.7MB/s]
# Downloading model.safetensors:  14% 168M/1.22G [00:06<00:39, 26.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 178M/3.44G [00:06<01:30, 36.0MB/s]
#
#
#
# Downloading model.safetensors:  45% 220M/492M [00:06<00:06, 44.4MB/s]
#
# Downloading (…)ch_model.safetensors:  53% 178M/335M [00:06<00:04, 35.4MB/s]
# Downloading model.safetensors:  15% 178M/1.22G [00:06<00:32, 32.4MB/s]
#
# Downloading (…)ch_model.safetensors:  56% 189M/335M [00:06<00:03, 42.6MB/s]
#
#
#
# Downloading model.safetensors:  47% 231M/492M [00:06<00:05, 49.6MB/s]
# Downloading model.safetensors:  16% 199M/1.22G [00:06<00:20, 49.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 199M/3.44G [00:06<01:10, 45.8MB/s]
# Downloading model.safetensors:  17% 210M/1.22G [00:06<00:17, 56.0MB/s]
#
#
#
# Downloading model.safetensors:  49% 241M/492M [00:06<00:04, 52.8MB/s]
#
# Downloading (…)ch_model.safetensors:  60% 199M/335M [00:06<00:02, 45.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 220M/3.44G [00:06<00:52, 60.8MB/s]
#
# Downloading (…)ch_model.safetensors:  63% 210M/335M [00:06<00:02, 54.4MB/s]
#
#
#
# Downloading model.safetensors:  53% 262M/492M [00:07<00:03, 66.6MB/s]
# Downloading model.safetensors:  19% 231M/1.22G [00:07<00:15, 65.2MB/s]
#
# Downloading (…)ch_model.safetensors:  66% 220M/335M [00:06<00:01, 60.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 241M/3.44G [00:06<00:44, 71.6MB/s]
#
#
#
# Downloading model.safetensors:  55% 273M/492M [00:07<00:03, 66.2MB/s]
# Downloading model.safetensors:  20% 241M/1.22G [00:07<00:14, 65.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 262M/3.44G [00:06<00:39, 81.2MB/s]
#
# Downloading (…)ch_model.safetensors:  72% 241M/335M [00:06<00:01, 73.1MB/s]
#
#
#
# Downloading model.safetensors:  60% 294M/492M [00:07<00:02, 77.5MB/s]
#
# Downloading (…)ch_model.safetensors:  75% 252M/335M [00:07<00:01, 75.0MB/s]
# Downloading model.safetensors:  22% 262M/1.22G [00:07<00:14, 67.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 273M/3.44G [00:07<00:44, 70.8MB/s]
#
#
#
# Downloading model.safetensors:  62% 304M/492M [00:07<00:02, 80.7MB/s]
#
#
#
# Downloading model.safetensors:  64% 315M/492M [00:07<00:02, 80.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 283M/3.44G [00:07<00:43, 71.8MB/s]
#
# Downloading (…)ch_model.safetensors:  81% 273M/335M [00:07<00:00, 78.7MB/s]
# Downloading model.safetensors:  23% 283M/1.22G [00:07<00:11, 80.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 294M/3.44G [00:07<00:43, 73.0MB/s]
#
#
#
# Downloading model.safetensors:  66% 325M/492M [00:07<00:02, 75.6MB/s]
# Downloading model.safetensors:  24% 294M/1.22G [00:07<00:12, 75.0MB/s]
#
# Downloading (…)ch_model.safetensors:  88% 294M/335M [00:07<00:00, 82.1MB/s]
#
#
#
# Downloading model.safetensors:  68% 336M/492M [00:07<00:02, 77.8MB/s]
# Downloading model.safetensors:  25% 304M/1.22G [00:07<00:11, 78.2MB/s]
#
# Downloading (…)ch_model.safetensors:  91% 304M/335M [00:07<00:00, 84.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 315M/3.44G [00:07<00:39, 79.4MB/s]
#
#
#
# Downloading model.safetensors:  72% 357M/492M [00:08<00:01, 69.5MB/s]
#
# Downloading (…)ch_model.safetensors:  97% 325M/335M [00:07<00:00, 79.9MB/s]
# Downloading model.safetensors:  27% 325M/1.22G [00:08<00:12, 70.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 336M/3.44G [00:07<00:41, 74.8MB/s]
# Downloading model.safetensors:  28% 336M/1.22G [00:08<00:12, 72.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 346M/3.44G [00:08<00:41, 74.3MB/s]
#
#
#
# Downloading model.safetensors:  77% 377M/492M [00:08<00:01, 76.8MB/s]
# Downloading model.safetensors:  28% 346M/1.22G [00:08<00:11, 76.4MB/s]
#
#
#
# Downloading model.safetensors:  79% 388M/492M [00:08<00:01, 70.1MB/s]
#
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:08<00:00, 50.4MB/s]
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:08<00:00, 39.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  11% 367M/3.44G [00:08<00:45, 67.9MB/s]
#
#
#
# Downloading model.safetensors:  83% 409M/492M [00:08<00:01, 81.5MB/s]
# Downloading model.safetensors:  30% 367M/1.22G [00:08<00:11, 71.1MB/s]
#
#
#
# Downloading model.safetensors:  85% 419M/492M [00:09<00:02, 31.8MB/s]
# Downloading model.safetensors:  31% 377M/1.22G [00:10<00:32, 25.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 388M/3.44G [00:09<01:28, 34.4MB/s]
#
#
#
# Downloading model.safetensors:  89% 440M/492M [00:10<00:01, 45.7MB/s]
# Downloading model.safetensors:  33% 398M/1.22G [00:10<00:20, 39.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 409M/3.44G [00:09<01:07, 44.6MB/s]
#
#
#
# Downloading model.safetensors:  94% 461M/492M [00:10<00:00, 57.6MB/s]
# Downloading model.safetensors:  34% 409M/1.22G [00:10<00:18, 44.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 430M/3.44G [00:10<00:54, 55.4MB/s]
#
#
#
# Downloading model.safetensors:  98% 482M/492M [00:10<00:00, 71.1MB/s]
# Downloading model.safetensors:  35% 430M/1.22G [00:10<00:13, 56.9MB/s]
#
#
# Downloading model.safetensors: 100% 492M/492M [00:10<00:00, 46.5MB/s]
#
# Downloading model.safetensors:  37% 451M/1.22G [00:10<00:10, 72.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 472M/3.44G [00:10<00:37, 79.0MB/s]
# Downloading model.safetensors:  39% 472M/1.22G [00:10<00:07, 93.3MB/s]
# Downloading model.safetensors:  41% 493M/1.22G [00:10<00:06, 113MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 493M/3.44G [00:10<00:33, 87.9MB/s]
# Downloading model.safetensors:  42% 514M/1.22G [00:11<00:05, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 514M/3.44G [00:10<00:29, 100MB/s]
# Downloading model.safetensors:  44% 535M/1.22G [00:11<00:04, 140MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 535M/3.44G [00:10<00:24, 118MB/s]
# Downloading model.safetensors:  46% 556M/1.22G [00:11<00:04, 156MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 556M/3.44G [00:10<00:21, 132MB/s]
# Downloading model.safetensors:  47% 577M/1.22G [00:11<00:03, 166MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 587M/3.44G [00:11<00:17, 159MB/s]
# Downloading model.safetensors:  50% 608M/1.22G [00:11<00:03, 182MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 619M/3.44G [00:11<00:16, 172MB/s]
# Downloading model.safetensors:  52% 629M/1.22G [00:11<00:03, 148MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 640M/3.44G [00:11<00:17, 160MB/s]
# Downloading model.safetensors:  53% 650M/1.22G [00:11<00:03, 146MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 661M/3.44G [00:11<00:18, 152MB/s]
# Downloading model.safetensors:  55% 671M/1.22G [00:12<00:03, 141MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 682M/3.44G [00:11<00:21, 129MB/s]
# Downloading model.safetensors:  57% 692M/1.22G [00:12<00:04, 119MB/s]
# Downloading model.safetensors:  59% 713M/1.22G [00:12<00:03, 135MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 703M/3.44G [00:12<00:30, 91.2MB/s]
# Downloading model.safetensors:  60% 734M/1.22G [00:12<00:03, 121MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 724M/3.44G [00:12<00:24, 109MB/s]
# Downloading model.safetensors:  62% 755M/1.22G [00:12<00:03, 134MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 744M/3.44G [00:12<00:21, 123MB/s]
# Downloading model.safetensors:  65% 786M/1.22G [00:12<00:02, 153MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 765M/3.44G [00:12<00:20, 132MB/s]
# Downloading model.safetensors:  66% 807M/1.22G [00:12<00:02, 155MB/s]
# Downloading model.safetensors:  68% 828M/1.22G [00:13<00:02, 154MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 786M/3.44G [00:12<00:23, 111MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 807M/3.44G [00:12<00:22, 118MB/s]
# Downloading model.safetensors:  70% 849M/1.22G [00:13<00:02, 128MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 828M/3.44G [00:13<00:21, 124MB/s]
# Downloading model.safetensors:  72% 870M/1.22G [00:13<00:02, 141MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 849M/3.44G [00:13<00:20, 124MB/s]
# Downloading model.safetensors:  73% 891M/1.22G [00:13<00:02, 123MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 870M/3.44G [00:13<00:18, 137MB/s]
# Downloading model.safetensors:  75% 912M/1.22G [00:13<00:02, 129MB/s]
#
#
# Downloading (…)ch_model.safetensors:  26% 891M/3.44G [00:13<00:19, 130MB/s]
# Downloading model.safetensors:  77% 933M/1.22G [00:14<00:02, 123MB/s]
#
#
# Downloading (…)ch_model.safetensors:  27% 912M/3.44G [00:13<00:19, 127MB/s]
# Downloading model.safetensors:  78% 954M/1.22G [00:14<00:02, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  27% 933M/3.44G [00:13<00:19, 128MB/s]
#
#
# Downloading (…)ch_model.safetensors:  28% 954M/3.44G [00:14<00:18, 133MB/s]
# Downloading model.safetensors:  80% 975M/1.22G [00:14<00:02, 114MB/s]
#
#
# Downloading (…)ch_model.safetensors:  28% 975M/3.44G [00:14<00:18, 135MB/s]
# Downloading model.safetensors:  82% 996M/1.22G [00:14<00:01, 116MB/s]
#
#
# Downloading (…)ch_model.safetensors:  29% 996M/3.44G [00:14<00:19, 125MB/s]
# Downloading model.safetensors:  84% 1.02G/1.22G [00:14<00:01, 118MB/s]
# Downloading model.safetensors:  85% 1.04G/1.22G [00:14<00:01, 126MB/s]
#
#
# Downloading (…)ch_model.safetensors:  30% 1.02G/3.44G [00:14<00:20, 118MB/s]
# Downloading model.safetensors:  87% 1.06G/1.22G [00:15<00:01, 125MB/s]
#
#
# Downloading (…)ch_model.safetensors:  30% 1.04G/3.44G [00:15<00:37, 63.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  30% 1.05G/3.44G [00:16<01:06, 35.8MB/s]
# Downloading model.safetensors:  89% 1.08G/1.22G [00:16<00:03, 37.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  31% 1.07G/3.44G [00:17<01:27, 27.2MB/s]
# Downloading model.safetensors:  90% 1.09G/1.22G [00:17<00:05, 24.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  32% 1.09G/3.44G [00:19<02:09, 18.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  33% 1.12G/3.44G [00:19<01:20, 28.7MB/s]
# Downloading model.safetensors:  91% 1.11G/1.22G [00:19<00:06, 16.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  34% 1.15G/3.44G [00:19<00:53, 42.8MB/s]
# Downloading model.safetensors:  92% 1.12G/1.22G [00:19<00:04, 18.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  34% 1.18G/3.44G [00:19<00:37, 59.4MB/s]
# Downloading model.safetensors:  94% 1.14G/1.22G [00:20<00:02, 26.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  35% 1.22G/3.44G [00:19<00:29, 75.5MB/s]
# Downloading model.safetensors:  96% 1.16G/1.22G [00:20<00:01, 37.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  36% 1.24G/3.44G [00:20<00:27, 81.0MB/s]
# Downloading model.safetensors:  97% 1.18G/1.22G [00:20<00:00, 47.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  37% 1.27G/3.44G [00:20<00:21, 100MB/s]
# Downloading model.safetensors:  99% 1.21G/1.22G [00:20<00:00, 59.1MB/s]
#
#
# Downloading model.safetensors: 100% 1.22G/1.22G [00:20<00:00, 58.5MB/s]
# Fetching 15 files:  27% 4/15 [00:20<01:02,  5.66s/it]
#
#
# Downloading (…)ch_model.safetensors:  38% 1.31G/3.44G [00:20<00:17, 120MB/s]
#
#
# Downloading (…)ch_model.safetensors:  39% 1.34G/3.44G [00:20<00:13, 151MB/s]
#
#
# Downloading (…)ch_model.safetensors:  40% 1.37G/3.44G [00:20<00:11, 172MB/s]
#
#
# Downloading (…)ch_model.safetensors:  41% 1.43G/3.44G [00:20<00:08, 231MB/s]
#
#
# Downloading (…)ch_model.safetensors:  43% 1.48G/3.44G [00:20<00:07, 277MB/s]
#
#
# Downloading (…)ch_model.safetensors:  44% 1.52G/3.44G [00:21<00:06, 279MB/s]
#
#
# Downloading (…)ch_model.safetensors:  45% 1.55G/3.44G [00:21<00:08, 224MB/s]
#
#
# Downloading (…)ch_model.safetensors:  46% 1.58G/3.44G [00:21<00:07, 237MB/s]
#
#
# Downloading (…)ch_model.safetensors:  47% 1.61G/3.44G [00:21<00:07, 245MB/s]
#
#
# Downloading (…)ch_model.safetensors:  48% 1.65G/3.44G [00:21<00:07, 253MB/s]
#
#
# Downloading (…)ch_model.safetensors:  49% 1.68G/3.44G [00:21<00:06, 261MB/s]
#
#
# Downloading (…)ch_model.safetensors:  50% 1.71G/3.44G [00:21<00:06, 267MB/s]
#
#
# Downloading (…)ch_model.safetensors:  51% 1.74G/3.44G [00:22<00:06, 274MB/s]
#
#
# Downloading (…)ch_model.safetensors:  52% 1.78G/3.44G [00:22<00:05, 301MB/s]
#
#
# Downloading (…)ch_model.safetensors:  53% 1.82G/3.44G [00:22<00:05, 281MB/s]
#
#
# Downloading (…)ch_model.safetensors:  54% 1.87G/3.44G [00:22<00:05, 284MB/s]
#
#
# Downloading (…)ch_model.safetensors:  55% 1.90G/3.44G [00:22<00:06, 234MB/s]
#
#
# Downloading (…)ch_model.safetensors:  56% 1.93G/3.44G [00:22<00:06, 237MB/s]
#
#
# Downloading (…)ch_model.safetensors:  57% 1.97G/3.44G [00:22<00:05, 260MB/s]
#
#
# Downloading (…)ch_model.safetensors:  58% 2.00G/3.44G [00:23<00:05, 267MB/s]
#
#
# Downloading (…)ch_model.safetensors:  59% 2.03G/3.44G [00:23<00:05, 266MB/s]
#
#
# Downloading (…)ch_model.safetensors:  60% 2.07G/3.44G [00:23<00:05, 262MB/s]
#
#
# Downloading (…)ch_model.safetensors:  61% 2.10G/3.44G [00:23<00:05, 260MB/s]
#
#
# Downloading (…)ch_model.safetensors:  62% 2.13G/3.44G [00:23<00:05, 244MB/s]
#
#
# Downloading (…)ch_model.safetensors:  63% 2.16G/3.44G [00:23<00:05, 244MB/s]
#
#
# Downloading (…)ch_model.safetensors:  64% 2.19G/3.44G [00:23<00:04, 254MB/s]
#
#
# Downloading (…)ch_model.safetensors:  65% 2.22G/3.44G [00:23<00:04, 257MB/s]
#
#
# Downloading (…)ch_model.safetensors:  66% 2.25G/3.44G [00:24<00:04, 250MB/s]
#
#
# Downloading (…)ch_model.safetensors:  66% 2.29G/3.44G [00:24<00:04, 250MB/s]
#
#
# Downloading (…)ch_model.safetensors:  67% 2.32G/3.44G [00:24<00:04, 249MB/s]
#
#
# Downloading (…)ch_model.safetensors:  68% 2.35G/3.44G [00:24<00:04, 249MB/s]
#
#
# Downloading (…)ch_model.safetensors:  69% 2.38G/3.44G [00:24<00:05, 183MB/s]
#
#
# Downloading (…)ch_model.safetensors:  70% 2.41G/3.44G [00:24<00:05, 197MB/s]
#
#
# Downloading (…)ch_model.safetensors:  71% 2.44G/3.44G [00:24<00:04, 215MB/s]
#
#
# Downloading (…)ch_model.safetensors:  72% 2.47G/3.44G [00:25<00:04, 215MB/s]
#
#
# Downloading (…)ch_model.safetensors:  73% 2.51G/3.44G [00:25<00:04, 210MB/s]
#
#
# Downloading (…)ch_model.safetensors:  74% 2.54G/3.44G [00:25<00:04, 223MB/s]
#
#
# Downloading (…)ch_model.safetensors:  75% 2.57G/3.44G [00:25<00:03, 227MB/s]
#
#
# Downloading (…)ch_model.safetensors:  76% 2.60G/3.44G [00:25<00:03, 230MB/s]
#
#
# Downloading (…)ch_model.safetensors:  77% 2.63G/3.44G [00:25<00:03, 223MB/s]
#
#
# Downloading (…)ch_model.safetensors:  77% 2.66G/3.44G [00:25<00:03, 233MB/s]
#
#
# Downloading (…)ch_model.safetensors:  78% 2.69G/3.44G [00:26<00:03, 237MB/s]
#
#
# Downloading (…)ch_model.safetensors:  79% 2.73G/3.44G [00:26<00:03, 228MB/s]
#
#
# Downloading (…)ch_model.safetensors:  80% 2.76G/3.44G [00:26<00:04, 150MB/s]
#
#
# Downloading (…)ch_model.safetensors:  81% 2.79G/3.44G [00:26<00:03, 172MB/s]
#
#
# Downloading (…)ch_model.safetensors:  82% 2.82G/3.44G [00:26<00:03, 196MB/s]
#
#
# Downloading (…)ch_model.safetensors:  83% 2.85G/3.44G [00:26<00:02, 196MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 2.88G/3.44G [00:27<00:02, 216MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 2.92G/3.44G [00:27<00:02, 225MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 2.95G/3.44G [00:27<00:02, 232MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 2.99G/3.44G [00:27<00:01, 269MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 3.02G/3.44G [00:27<00:01, 259MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 3.06G/3.44G [00:27<00:01, 292MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 3.09G/3.44G [00:27<00:01, 254MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 3.12G/3.44G [00:27<00:01, 267MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 3.16G/3.44G [00:29<00:03, 75.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 3.19G/3.44G [00:29<00:02, 95.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 3.23G/3.44G [00:29<00:01, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 3.26G/3.44G [00:29<00:01, 137MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 3.30G/3.44G [00:29<00:00, 175MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 3.33G/3.44G [00:29<00:00, 188MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 3.38G/3.44G [00:29<00:00, 204MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 3.44G/3.44G [00:30<00:00, 114MB/s]
# Fetching 15 files: 100% 15/15 [00:30<00:00,  2.05s/it]
# /usr/local/lib/python3.8/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# Downloading (…)okenizer_config.json: 100% 255/255 [00:00<00:00, 41.4kB/s]
# Downloading (…)olve/main/vocab.json: 100% 798k/798k [00:00<00:00, 43.2MB/s]
# Downloading (…)olve/main/merges.txt: 100% 456k/456k [00:00<00:00, 44.9MB/s]
# Downloading (…)/main/tokenizer.json: 100% 2.11M/2.11M [00:00<00:00, 68.0MB/s]
# Downloading (…)cial_tokens_map.json: 100% 99.0/99.0 [00:00<00:00, 54.2kB/s]
# Downloading (…)lve/main/config.json: 100% 912/912 [00:00<00:00, 488kB/s]
# Downloading pytorch_model.bin: 100% 510M/510M [00:06<00:00, 82.7MB/s]
# Running on local URL:  http://0.0.0.0:7860
# Running on public URL: https://ade83f300e1de769ca.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# ===============Running run_text =============
# Inputs: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车” []
# ======>Previous memory:
#  human_prefix='Human' ai_prefix='AI' buffer='' output_key='output' input_key=None memory_key='chat_history'
# hitory_memory:, n_tokens: 0
#
#
# > Entering new AgentExecutor chain...
#
# Yes
# Action: Generate Image From User Input Text
# Action Input: "dog in space wearing astronaut suit, with Jupiter in the background, driving a space motorcycle"/usr/local/lib/python3.8/site-packages/transformers/generation/utils.py:1186: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.8/site-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 50 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# dog in space wearing astronaut suit, with Jupiter in the background, driving a space motorcycle refined to dog in space wearing astronaut suit, with Jupiter in the background, driving a space motorcycle through a nebula, intricate, elegant, highly detailed, digital painting, artstation, concept art, smooth, sharp focus, colored illustration for tattoo, art by
# 100% 50/50 [00:11<00:00,  4.34it/s]
# Processed T2I.run, text: dog in space wearing astronaut suit, with Jupiter in the background, driving a space motorcycle, image_filename: image/dd9d4bcc.png
#
# Observation: image/dd9d4bcc.png
# Thought: Do I need to use a tool?
# No
# AI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.
#
# > Finished chain.
# ======>Current memory:
#  human_prefix='Human' ai_prefix='AI' buffer='\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.' output_key='output' input_key=None memory_key='chat_history'
# Outputs: [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is ![](/file=image/dd9d4bcc.png)*image/dd9d4bcc.png*.')]
# ===============Running run_text =============
# Inputs: 文生图的模型用的是什么？ [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.')]
# ======>Previous memory:
#  human_prefix='Human' ai_prefix='AI' buffer='\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.' output_key='output' input_key=None memory_key='chat_history'
# hitory_memory:
# Human: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”
# AI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png., n_tokens: 32
#
#
# > Entering new AgentExecutor chain...
#
# No
# AI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.
#
# > Finished chain.
# ======>Current memory:
#  human_prefix='Human' ai_prefix='AI' buffer='\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.' output_key='output' input_key=None memory_key='chat_history'
# Outputs: [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.')]
# ===============Running run_text =============
# Inputs: 是stable diffusion吗 [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.')]
# ======>Previous memory:
#  human_prefix='Human' ai_prefix='AI' buffer='\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.' output_key='output' input_key=None memory_key='chat_history'
# hitory_memory:
# Human: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”
# AI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.
# Human: 文生图的模型用的是什么？
# AI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions., n_tokens: 65
#
#
# > Entering new AgentExecutor chain...
#  No
# AI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.
#
# > Finished chain.
# ======>Current memory:
#  human_prefix='Human' ai_prefix='AI' buffer='\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: 是stable diffusion吗\nAI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.' output_key='output' input_key=None memory_key='chat_history'
# Outputs: [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('是stable diffusion吗', 'No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.')]
# ===============Running run_text =============
# Inputs: what's your name [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('是stable diffusion吗', 'No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.')]
# ======>Previous memory:
#  human_prefix='Human' ai_prefix='AI' buffer='\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: 是stable diffusion吗\nAI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.' output_key='output' input_key=None memory_key='chat_history'
# hitory_memory:
# Human: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”
# AI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.
# Human: 文生图的模型用的是什么？
# AI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.
# Human: 是stable diffusion吗
# AI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions., n_tokens: 105
#
#
# > Entering new AgentExecutor chain...
#  No
# AI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.
#
# > Finished chain.
# ======>Current memory:
#  human_prefix='Human' ai_prefix='AI' buffer="\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: 是stable diffusion吗\nAI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: what's your name\nAI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks." output_key='output' input_key=None memory_key='chat_history'
# Outputs: [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('是stable diffusion吗', 'No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ("what's your name", 'My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.')]
# ===============Running run_text =============
# Inputs: can you process videos [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('是stable diffusion吗', 'No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('what’s your name', 'My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.')]
# ======>Previous memory:
#  human_prefix='Human' ai_prefix='AI' buffer="\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: 是stable diffusion吗\nAI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: what's your name\nAI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks." output_key='output' input_key=None memory_key='chat_history'
# hitory_memory:
# Human: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”
# AI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.
# Human: 文生图的模型用的是什么？
# AI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.
# Human: 是stable diffusion吗
# AI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.
# Human: what's your name
# AI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks., n_tokens: 134
#
#
# > Entering new AgentExecutor chain...
#
# No
# AI: Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them.
#
# > Finished chain.
# ======>Current memory:
#  human_prefix='Human' ai_prefix='AI' buffer="\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: 是stable diffusion吗\nAI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: what's your name\nAI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.\nHuman: can you process videos\nAI: Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them." output_key='output' input_key=None memory_key='chat_history'
# Outputs: [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('是stable diffusion吗', 'No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('what’s your name', 'My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.'), ('can you process videos', 'Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them.')]
# ===============Running run_text =============
# Inputs: which tools can be used to deal with videos [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('是stable diffusion吗', 'No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('what’s your name', 'My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.'), ('can you process videos', 'Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them.')]
# ======>Previous memory:
#  human_prefix='Human' ai_prefix='AI' buffer="\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: 是stable diffusion吗\nAI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: what's your name\nAI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.\nHuman: can you process videos\nAI: Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them." output_key='output' input_key=None memory_key='chat_history'
# hitory_memory:
# Human: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”
# AI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.
# Human: 文生图的模型用的是什么？
# AI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.
# Human: 是stable diffusion吗
# AI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.
# Human: what's your name
# AI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.
# Human: can you process videos
# AI: Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them., n_tokens: 166
#
#
# > Entering new AgentExecutor chain...
#
# Yes
# Action: Get Photo Description
# Action Input: video_pathTraceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/gradio/routes.py", line 384, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.8/site-packages/gradio/blocks.py", line 1032, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.8/site-packages/gradio/blocks.py", line 844, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.8/site-packages/anyio/to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.8/site-packages/anyio/_backends/_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.8/site-packages/anyio/_backends/_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "visual_chatgpt.py", line 908, in run_text
#     res = self.agent({"input": text})
#   File "/usr/local/lib/python3.8/site-packages/langchain/chains/base.py", line 168, in __call__
#     raise e
#   File "/usr/local/lib/python3.8/site-packages/langchain/chains/base.py", line 165, in __call__
#     outputs = self._call(inputs)
#   File "/usr/local/lib/python3.8/site-packages/langchain/agents/agent.py", line 503, in _call
#     next_step_output = self._take_next_step(
#   File "/usr/local/lib/python3.8/site-packages/langchain/agents/agent.py", line 420, in _take_next_step
#     observation = tool.run(
#   File "/usr/local/lib/python3.8/site-packages/langchain/tools/base.py", line 71, in run
#     raise e
#   File "/usr/local/lib/python3.8/site-packages/langchain/tools/base.py", line 68, in run
#     observation = self._run(tool_input)
#   File "/usr/local/lib/python3.8/site-packages/langchain/agents/tools.py", line 17, in _run
#     return self.func(tool_input)
#   File "visual_chatgpt.py", line 213, in inference
#     inputs = self.processor(Image.open(image_path), return_tensors="pt").to(self.device)
#   File "/usr/local/lib/python3.8/site-packages/PIL/Image.py", line 3227, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: 'video_path'
# ===============Running run_text =============
# ...
# Outputs: [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('是stable diffusion吗', 'No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('what’s your name', 'My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.'), ('can you process videos', 'Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them.'), ('which tools', 'The image I generated is of an astronaut in space, with a space shuttle in the background. The image file name is ![](/file=image/dd9d4bcc.png)*image/dd9d4bcc.png*.')]
# ===============Running run_text =============
# Inputs: I mean which tools can be used to process videos [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('是stable diffusion吗', 'No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('what’s your name', 'My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.'), ('can you process videos', 'Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them.'), ('which tools', 'The image I generated is of an astronaut in space, with a space shuttle in the background. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.')]
# ======>Previous memory:
#  human_prefix='Human' ai_prefix='AI' buffer="\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: 是stable diffusion吗\nAI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: what's your name\nAI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.\nHuman: can you process videos\nAI: Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them.\nHuman: which tools\nAI: The image I generated is of an astronaut in space, with a space shuttle in the background. The image file name is image/dd9d4bcc.png." output_key='output' input_key=None memory_key='chat_history'
# hitory_memory:
# Human: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”
# AI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.
# Human: 文生图的模型用的是什么？
# AI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.
# Human: 是stable diffusion吗
# AI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.
# Human: what's your name
# AI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.
# Human: can you process videos
# AI: Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them.
# Human: which tools
# AI: The image I generated is of an astronaut in space, with a space shuttle in the background. The image file name is image/dd9d4bcc.png., n_tokens: 193
#
#
# > Entering new AgentExecutor chain...
#
# Yes
# Action: Get Photo Description
# Action Input: image/dd9d4bcc.png
# Observation: an astronaut in space, with a space shuttle shuttle shuttle in the background
# Thought: Do I need to use a tool?
# No
# AI: The tools that can be used to process videos include video analysis tools such as OpenCV, video recognition tools such as Google Cloud Video Intelligence, and video captioning tools such as Microsoft Azure Video Indexer.
#
# > Finished chain.
# ======>Current memory:
#  human_prefix='Human' ai_prefix='AI' buffer="\nHuman: 帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”\nAI: I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is image/dd9d4bcc.png.\nHuman: 文生图的模型用的是什么？\nAI: The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: 是stable diffusion吗\nAI: No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.\nHuman: what's your name\nAI: My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.\nHuman: can you process videos\nAI: Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them.\nHuman: which tools\nAI: The image I generated is of an astronaut in space, with a space shuttle in the background. The image file name is image/dd9d4bcc.png.\nHuman: I mean which tools can be used to process videos\nAI: The tools that can be used to process videos include video analysis tools such as OpenCV, video recognition tools such as Google Cloud Video Intelligence, and video captioning tools such as Microsoft Azure Video Indexer." output_key='output' input_key=None memory_key='chat_history'
# Outputs: [('帮我生成一张图片，提示词如下：“狗在太空里面，穿着宇航服，背后是木星，驾驶着宇宙摩托车”', 'I have generated an image of a dog in space wearing an astronaut suit, with Jupiter in the background, driving a space motorcycle. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('文生图的模型用的是什么？', 'The model used for generating images from text is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('是stable diffusion吗', 'No, the model used for generating images from text is not stable diffusion. It is a Generative Adversarial Network (GAN). GANs are a type of deep learning model that can generate realistic images from text descriptions.'), ('what’s your name', 'My name is Visual ChatGPT. I am a text language model designed to assist with a wide range of text and visual related tasks.'), ('can you process videos', 'Visual ChatGPT is a text language model, so it cannot directly process videos. However, it can use tools to observe videos and extract information from them.'), ('which tools', 'The image I generated is of an astronaut in space, with a space shuttle in the background. The image file name is <img src="/file=image/dd9d4bcc.png" alt=""><em>image/dd9d4bcc.png</em>.'), ('I mean which tools can be used to process videos', 'The tools that can be used to process videos include video analysis tools such as OpenCV, video recognition tools such as Google Cloud Video Intelligence, and video captioning tools such as Microsoft Azure Video Indexer.')]
# Keyboard interruption in main thread... closing server.
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /usr/local/lib/python3.8/site-packages/gradio/blocks.py:1680 in block_thread │
# │                                                                              │
# │   1677 │   │   """Block main thread until interrupted by user."""            │
# │   1678 │   │   try:                                                          │
# │   1679 │   │   │   while True:                                               │
# │ ❱ 1680 │   │   │   │   time.sleep(0.1)                                       │
# │   1681 │   │   except (KeyboardInterrupt, OSError):                          │
# │   1682 │   │   │   print("Keyboard interruption in main thread... closing se │
# │   1683 │   │   │   self.server.close()                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/visual-chatgpt-googlecolab/visual_chatgpt.py:958 in <module>        │
# │                                                                              │
# │   955 │   │   clear.click(bot.memory.clear)                                  │
# │   956 │   │   clear.click(lambda: [], None, chatbot)                         │
# │   957 │   │   clear.click(lambda: [], None, state)                           │
# │ ❱ 958 │   │   demo.launch(server_name="0.0.0.0", server_port=7860, share=Tru │
# │   959                                                                        │
# │                                                                              │
# │ /usr/local/lib/python3.8/site-packages/gradio/blocks.py:1597 in launch       │
# │                                                                              │
# │   1594 │   │   is_in_interactive_mode = bool(getattr(sys, "ps1", sys.flags.i │
# │   1595 │   │                                                                 │
# │   1596 │   │   if not prevent_thread_lock and not is_in_interactive_mode:    │
# │ ❱ 1597 │   │   │   self.block_thread()                                       │
# │   1598 │   │                                                                 │
# │   1599 │   │   return TupleNoPrint((self.server_app, self.local_url, self.sh │
# │   1600                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.8/site-packages/gradio/blocks.py:1683 in block_thread │
# │                                                                              │
# │   1680 │   │   │   │   time.sleep(0.1)                                       │
# │   1681 │   │   except (KeyboardInterrupt, OSError):                          │
# │   1682 │   │   │   print("Keyboard interruption in main thread... closing se │
# │ ❱ 1683 │   │   │   self.server.close()                                       │
# │   1684 │   │   │   for tunnel in CURRENT_TUNNELS:                            │
# │   1685 │   │   │   │   tunnel.kill()                                         │
# │   1686                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.8/site-packages/gradio/networking.py:43 in close      │
# │                                                                              │
# │    40 │                                                                      │
# │    41 │   def close(self):                                                   │
# │    42 │   │   self.should_exit = True                                        │
# │ ❱  43 │   │   self.thread.join()                                             │
# │    44                                                                        │
# │    45                                                                        │
# │    46 def get_first_available_port(initial: int, final: int) -> int:         │
# │                                                                              │
# │ /usr/local/lib/python3.8/threading.py:1011 in join                           │
# │                                                                              │
# │   1008 │   │   │   raise RuntimeError("cannot join current thread")          │
# │   1009 │   │                                                                 │
# │   1010 │   │   if timeout is None:                                           │
# │ ❱ 1011 │   │   │   self._wait_for_tstate_lock()                              │
# │   1012 │   │   else:                                                         │
# │   1013 │   │   │   # the behavior of a negative timeout isn't documented, bu │
# │   1014 │   │   │   # historically .join(timeout=x) for x<0 has acted as if t │
# │                                                                              │
# │ /usr/local/lib/python3.8/threading.py:1027 in _wait_for_tstate_lock          │
# │                                                                              │
# │   1024 │   │   lock = self._tstate_lock                                      │
# │   1025 │   │   if lock is None:  # already determined that the C code is don │
# │   1026 │   │   │   assert self._is_stopped                                   │
# │ ❱ 1027 │   │   elif lock.acquire(block, timeout):                            │
# │   1028 │   │   │   lock.release()                                            │
# │   1029 │   │   │   self._stop()                                              │
# │   1030                                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
# Killing tunnel 0.0.0.0:7860 <> https://ade83f300e1de769ca.gradio.live
# ^C
